# %% [markdown]
# <a href="https://colab.research.google.com/github/Taneyquezada/Estadistica/blob/main/eii_u2_04_22150442.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conjunto de datos de cadena de suministro

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

df.drop(columns = ["Timestamp", "Asset_ID"], inplace = True)

df
# Out:
#      Latitude  Longitude  Inventory_Level Shipment_Status  Temperature  \
# 1     22.2748  -131.7086              491      In Transit         22.5
# 3     42.3900    -1.4788              330       Delivered         25.4
# 7     46.5643  -126.5348              222      In Transit         23.3
# 9     54.1683  -135.2676              389      In Transit         21.9
# 11   -25.2768   156.1262              234       Delivered         29.7
# ..        ...        ...              ...             ...          ...
# 993   46.9729   -36.5198              420         Delayed         21.6
# 994   44.2477   175.0702              143       Delivered         21.6
# 995   89.8701    73.6867              264       Delivered         26.9
# 996  -10.4792  -177.1239              479       Delivered         23.7
# 999   59.8356  -114.4198              157         Delayed         18.7
#
#      Humidity Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# ...

# %%
#Latitude
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

sns.histplot(df["Latitude"], kde = True, color = "red")

plt.xlabel("Latitude")
plt.ylabel("Frecuencia")
plt.title("Distribución de Latitude")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Longitude
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Longitude"], kde = True, color = "red")

plt.xlabel("Longitude")
plt.ylabel("Frecuencia")
plt.title("Distribución de Longitude")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Inventory_Level
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Inventory_Level"], kde = True, color = "red")

plt.xlabel("Inventory_Level")
plt.ylabel("Frecuencia")
plt.title("Distribución de Inventory_Level")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Shipment_Status
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

modelo = smf.ols("Demand_Forecast ~ C(Shipment_Status)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #ANOVA de una vía
tabla_anova
# Out:
#                        df        sum_sq      mean_sq         F    PR(>F)
# C(Shipment_Status)    2.0  1.475267e+03   737.633369  0.204823  0.814838
# Residual            734.0  2.643370e+06  3601.322111       NaN       NaN

# %%
#Temperature
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Temperature"], kde = True, color = "red")

plt.xlabel("Temperature")
plt.ylabel("Frecuencia")
plt.title("Distribución de Temperature")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Humidity
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Humidity"], kde = True, color = "red")

plt.xlabel("Humidity")
plt.ylabel("Frecuencia")
plt.title("Distribución de Humidity")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Traffic_Status

import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

modelo = smf.ols("Demand_Forecast ~ C(Traffic_Status)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #ANOVA de una vía
tabla_anova
# Out:
#                       df        sum_sq      mean_sq         F    PR(>F)
# C(Traffic_Status)    2.0  1.996710e+03   998.355010  0.277274  0.757926
# Residual           734.0  2.642849e+06  3600.611698       NaN       NaN

# %%
#User_Transaction_Amount
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["User_Transaction_Amount"], kde = True, color = "red")

plt.xlabel("User_Transaction_Amount")
plt.ylabel("Frecuencia")
plt.title("Distribución de User_Transaction_Amount")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#User_Purchase_Frequency
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["User_Purchase_Frequency"], kde = True, color = "red")

plt.xlabel("User_Purchase_Frequency")
plt.ylabel("Frecuencia")
plt.title("Distribución de User_Purchase_Frequency")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Logistics_Delay_Reason

import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols("Demand_Forecast ~ C(Logistics_Delay_Reason)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #ANOVA de una vía
tabla_anova
# Out:
#                               df        sum_sq      mean_sq         F   PR(>F)
# C(Logistics_Delay_Reason)    2.0  4.733721e+02   236.686041  0.065697  0.93642
# Residual                   734.0  2.644372e+06  3602.687090       NaN      NaN

# %%
#Asset_Utilization

import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Asset_Utilization"], kde = True, color = "red")

plt.xlabel("Asset_Utilization")
plt.ylabel("Frecuencia")
plt.title("Distribución de Asset_Utilization")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Waiting_Time

import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Waiting_Time"], kde = True, color = "red")

plt.xlabel("Waiting_Time")
plt.ylabel("Frecuencia")
plt.title("Distribución de Waiting_Time")

plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)

# %%
#Logistics_Delay

import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols("Demand_Forecast ~ C(Logistics_Delay)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #ANOVA de una vía
tabla_anova
# Out:
#                        df        sum_sq      mean_sq         F    PR(>F)
# C(Logistics_Delay)    1.0  4.344407e+01    43.444073  0.012073  0.912536
# Residual            735.0  2.644802e+06  3598.370411       NaN       NaN

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

df.drop(columns = ["Timestamp", "Asset_ID", "Shipment_Status", "Traffic_Status", "User_Purchase_Frequency", "Logistics_Delay_Reason", "Logistics_Delay"], inplace = True)

df
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 1     22.2748  -131.7086              491         22.5      54.3
# 3     42.3900    -1.4788              330         25.4      52.3
# 7     46.5643  -126.5348              222         23.3      64.2
# 9     54.1683  -135.2676              389         21.9      57.3
# 11   -25.2768   156.1262              234         29.7      63.6
# ..        ...        ...              ...          ...       ...
# 993   46.9729   -36.5198              420         21.6      62.8
# 994   44.2477   175.0702              143         21.6      64.1
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 999   59.8356  -114.4198              157         18.7      73.6
#
#      Waiting_Time  User_Transaction_Amount  Asset_Utilization  Demand_Forecast
# 1              16                      439               80.9              174
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)

df.drop(columns = ["Timestamp", "Asset_ID", "Shipment_Status", "Traffic_Status", "User_Purchase_Frequency", "Logistics_Delay_Reason", "Logistics_Delay"], inplace = True)


matriz_de_correlación = df.corr()
plt.figure(figsize = (15,9))
sns.heatmap(matriz_de_correlación, annot = True, fmt = "0.2f", square= True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de Correlación')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm

X = df[['Longitude',"Asset_Utilization"]]
Y = df['Demand_Forecast']

X_train, X_test,  Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()

Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test,Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinación: {r2: 0.4f}')
print("\n")
# Out:
# Coeficiente de determinación: -0.0045

# %% [markdown]
# El modelo actual no es adecuado para predecir "Demand_Forecast" con las variables "Longitude" y "Asset_Utilization". No se forma ninguna recta, por lo que al estar los puntos tan dispersos, es dificil tener una predicción de los datos, por lo que no es un buen modelo de estudio.

# %%
b0,b1,b2,b3,b4,b5,b6,b7,b8 = modelo.params
fun = lambda x1,x2,x3,x4,x5,x6,x7,x8: b0 + b1 * x1 + b2 * x2 + b3 * x3 + b4 * x4 + b5 * x5 + b6 * x6 + b7 * x7 + b8 * x8
fun(46.5643, -131.7086, 157, 26.9, 63.6, 32, 459, 80.9 )
# Out:
# 192.96520470369632

# %%
from statsmodels.formula.api import ols
modelo_2 = ols('Demand_Forecast ~ Latitude+Longitude+Inventory_Level+Temperature+Humidity+Waiting_Time+User_Transaction_Amount+Asset_Utilization', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2, typ = 2)
tabla_anova
# Out:
#                                sum_sq     df          F    PR(>F)
# Latitude                 3.001982e+01    1.0   0.008523  0.926468
# Longitude                4.023065e+04    1.0  11.422425  0.000764
# Inventory_Level          2.123730e+03    1.0   0.602977  0.437697
# Temperature              4.103097e+02    1.0   0.116497  0.732964
# Humidity                 3.339190e+02    1.0   0.094807  0.758240
# Waiting_Time             9.999683e+02    1.0   0.283914  0.594310
# User_Transaction_Amount  1.639951e+03    1.0   0.465621  0.495226
# Asset_Utilization        3.588950e+04    1.0  10.189871  0.001473
# Residual                 2.564072e+06  728.0        NaN       NaN

# %% [markdown]
# Longitude (p = 0.000764): Esta variable tiene un efecto significativo en la variable dependiente.
#
# Asset_Utilization (p = 0.001473): También es significativa.
#
# Latitude, Inventory_Level, Temperature, Humidity, Waiting_Time, y User_Transaction_Amount no tienen un efecto significativo en la variable dependiente.
#
# Shipment_Status se elimina ya que no hay pruebas de que tenga relación con la variable según ANOVA.
#
# Traffic_Status se elimina ya que no hay pruebas de que tenga relación con la variable según ANOVA.
#
# User_Purchase_Frequency contiene un dato atípico, por lo que se elimina para no afectar el modelo.
#
# Logistics_Delay_Reason se elimina ya que no hay pruebas de que tenga relación con la variable según ANOVA.
#
# Logistics_Delay se elimina ya que no hay pruebas de que tenga relación con la variable según ANOVA.
#
# Demand_Forecast  es la variable dependiente, distribución normal, sin datos atípicos
