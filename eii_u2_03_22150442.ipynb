# %% [markdown]
# # STUDENT PERFORMANCE FACTORS

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Angelgz011/estadistica2/refs/heads/main/StudentPerformanceFactors.csv")
df.dropna(inplace=True)

df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.drop(columns = ['School_Type'], inplace = True)
df.drop(columns = ['Gender'], inplace = True)

niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Parental_Involvement'] = df['Parental_Involvement'].map(niveles)

niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Access_to_Resources'] = df['Access_to_Resources'].map(niveles)

niveles = {'No': 0, 'Yes': 1}
df['Extracurricular_Activities'] = df['Extracurricular_Activities'].map(niveles)

niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Motivation_Level'] = df['Motivation_Level'].map(niveles)

niveles = {'Yes': 1, 'No': 0}
df['Internet_Access'] = df['Internet_Access'].map(niveles)

niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Family_Income'] = df['Family_Income'].map(niveles)

niveles = {'Low': 0, 'Medium': 0, 'High': 100}
df['Teacher_Quality'] = df['Teacher_Quality'].map(niveles)

niveles = {'Negative': -1, 'Neutral': 0, 'Positive': 1}
df['Peer_Influence'] = df['Peer_Influence'].map(niveles)

niveles = {'No': 0, 'Yes': 1}
df['Learning_Disabilities'] = df['Learning_Disabilities'].map(niveles)

niveles = {'College': 0, 'High School': 50, 'Postgraduate': 100}
df['Parental_Education_Level'] = df['Parental_Education_Level'].map(niveles)

niveles = {'Far': 0, 'Moderate': 50, 'Near': 100}
df['Distance_from_Home'] = df['Distance_from_Home'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matriz_de_correlación = df.corr()
plt.figure(figsize = (15,9))
sns.heatmap(matriz_de_correlación, annot = True, fmt = "0.2f", square= True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de Correlación')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm

X = df[['Hours_Studied','Attendance','Parental_Involvement','Access_to_Resources','Previous_Scores','Tutoring_Sessions','Peer_Influence','Distance_from_Home']]
Y = df['Exam_Score']

X_train, X_test,  Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()

Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test,Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinación: {r2: 0.4f}')
print("\n")
# Out:
# Coeficiente de determinación:  0.6935

# %%
b0,b1,b2,b3,b4,b5,b6,b7,b8 = modelo.params
fun = lambda x1,x2,x3,x4,x5,x6,x7,x8: b0 + b1 * x1 + b2 * x2 + b3 * x3 + b4 * x4 + b5 * x5 + b6 * x6 + b7 * x7 + b8 * x8
fun(15, 50, 50, 50, 70, 2, 0, 50 )
# Out:
# 59.33058032785334

# %%
from statsmodels.formula.api import ols
modelo_2 = ols('Exam_Score ~ Hours_Studied+Attendance+Parental_Involvement+Access_to_Resources+Previous_Scores+Tutoring_Sessions+Peer_Influence+Distance_from_Home', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2, typ = 2)
tabla_anova
# Out:
#                             sum_sq      df            F         PR(>F)
# Hours_Studied         19706.195500     1.0  3901.825008   0.000000e+00
# Attendance            33569.292653     1.0  6646.717048   0.000000e+00
# Parental_Involvement   2975.150701     1.0   589.079582  1.558603e-124
# Access_to_Resources    3166.349169     1.0   626.936862  4.744512e-132
# Previous_Scores        3070.534554     1.0   607.965577  2.739916e-128
# Tutoring_Sessions      2461.434279     1.0   487.363775  3.954966e-104
# Peer_Influence          999.231773     1.0   197.847805   2.817827e-44
# Distance_from_Home      626.602099     1.0   124.067161   1.492979e-28
# Residual              32166.680687  6369.0          NaN            NaN

# %% [markdown]
# Hours_Studied, Distribución normal sin datos atipicos.
#
# Attendance, Distribución uniforme, sin datos atípicos.
#
# Parental_Involvement, Niveles de medición Low, Medium, High. Hay un aumento entre
# la participación parental y calificación del alumno.
#
#
# Access_to_Resources, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación,
# entre más acceso a recursos.
#
#
# Extracurricular_Activities, Niveles de medición No, Yes.
#
#
# Sleep_Hours, Sigue una distribución normal. No hay datos atípicos.
#
# Previous_Scores, Distribución uniforme. No hay datos atípicos.
#
#
# Motivation_Level, Niveles de medición Low, Medium, High. Existe un aumento en la calificación, entre más motivado.
#
#
# Internet_Access, Niveles de medición Yes, No. Existe un aumento en la calificación, entre más acceso a internet.
#
#
# Tutoring_Sessions, Distribución mas cercana a la Poisson. No hay datos atípicos.
#
# Family_Income, Niveles de medición Low, Medium, High. Existe un aumento en la calificación, entre más ingreso familiar.
#
#
#
# Teacher_Quality, Niveles de medición Low, medium, high, donde low y medium son una misma.
#
# School_Type, Se elimina la columna por que no aporta información.
#
#
# Peer_Influence, Niveles de medición Negative, Neutral, Positive. Existe un aumento
# en la calificación, entre más influye el profesor.
#
# Physical_Activity, Distribución normal, sin datos atípicos.
#
# Learning_Disabilities, niveles de medición No, Yes. Hay una menor calificación si hay discapacidades.
#
# Parental_Education_Level, niveles de medición College, High School, Postgraduate.
# Existe un aumento en la calificación conforme a la educación del padre.
#
# Distance_from_Home,Niveles de medición Far, Moderate, Near. Existe un aumento en la calificación,
# entre más cerca se vive de la escuela.
#
# Gender, Se elimina la columna por que no aporta información relevante.
#
# Exam_Score, Se puede ver una distribución normal sin presentar datos atípicos significativos.
#
#
# Según el mapa de calor se aprecian pocas variables que tienen una relación fuerte,
# siendo las horas estudiadas y la asistencia las que mejor demuestran una correlación.

# %% [markdown]
# # CHURN MODELING

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Taneyquezada/Estadistica/refs/heads/main/Churn_Modelling.csv")
df.dropna(inplace=True)

df.drop(columns = ["RowNumber", "CustomerId", "Surname","Geography", "Gender"], inplace = True )
df
# Out:
#        CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0              619  42.0       2       0.00              1        1.0
# 1              608  41.0       1   83807.86              1        0.0
# 2              502  42.0       8  159660.80              3        1.0
# 3              699  39.0       1       0.00              2        0.0
# 5              645  44.0       8  113755.78              2        1.0
# ...            ...   ...     ...        ...            ...        ...
# 9997           709  36.0       7       0.00              1        0.0
# 9998           772  42.0       3   75075.31              2        1.0
# 9999           772  42.0       3   75075.31              2        1.0
# 10000          792  28.0       4  130142.79              1        1.0
# 10001          792  28.0       4  130142.79              1        1.0
#
#        IsActiveMember  EstimatedSalary  Exited
# 0                 1.0        101348.88       1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matriz_de_correlación = df.corr()
plt.figure(figsize = (15,9))
sns.heatmap(matriz_de_correlación, annot = True, fmt = "0.2f", square= True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de Correlación')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm

X = df[['CreditScore','Age','Tenure','Balance',"NumOfProducts", 'HasCrCard','IsActiveMember']]
Y = df['EstimatedSalary']

X_train, X_test,  Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()

Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test,Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinación: {r2: 0.4f}')
print("\n")
df
# Out:
# Coeficiente de determinación: -0.0039
#        CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0              619  42.0       2       0.00              1        1.0
# 1              608  41.0       1   83807.86              1        0.0
# 2              502  42.0       8  159660.80              3        1.0
# 3              699  39.0       1       0.00              2        0.0
# 5              645  44.0       8  113755.78              2        1.0
# ...            ...   ...     ...        ...            ...        ...
# 9997           709  36.0       7       0.00              1        0.0
# 9998           772  42.0       3   75075.31              2        1.0
# 9999           772  42.0       3   75075.31              2        1.0
# 10000          792  28.0       4  130142.79              1        1.0
# 10001          792  28.0       4  130142.79              1        1.0
#
#        IsActiveMember  EstimatedSalary  Exited
# ...

# %%
b0,b1,b2,b3,b4,b5,b6, b7 = modelo.params
fun = lambda x1,x2,x3,x4,x5,x6,x7: b0 + b1 * x1 + b2 * x2 + b3 * x3 + b4 * x4 + b5 * x5 + b6 * x6 + b7 * x7
fun(792, 42, 1, 130142.79, 3, 1, 0 )
# Out:
# 104302.6760526397

# %%
from statsmodels.formula.api import ols
modelo_2 = ols('EstimatedSalary ~ CreditScore+Age+Tenure+Balance+NumOfProducts+HasCrCard+IsActiveMember', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2, typ = 2)
tabla_anova
# Out:
#                       sum_sq      df         F    PR(>F)
# CreditScore     6.997193e+07     1.0  0.021158  0.884351
# Age             1.186456e+09     1.0  0.358767  0.549206
# Tenure          1.943219e+09     1.0  0.587601  0.443367
# Balance         1.050424e+10     1.0  3.176325  0.074743
# NumOfProducts   1.191605e+10     1.0  3.603238  0.057696
# HasCrCard       3.365491e+09     1.0  1.017675  0.313096
# IsActiveMember  3.527535e+09     1.0  1.066674  0.301723
# Residual        3.303734e+13  9990.0       NaN       NaN

# %% [markdown]
# Se descarta "RowNumber", "CustomerId", "Surname","Geography", "Gender", ya que no aportan valores significativos.
#
# El coeficiente de determinación al ser igual a -0.0039 quiere decir que es malo, por lo que el modelo no se ajusta bien a los datos.
